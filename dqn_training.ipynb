# %% [markdown]
# <a href="https://colab.research.google.com/github/dercodeKoenig/dqn_trading_gcloudvm/blob/main/dqn_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/drive/MyDrive/
# !ls
# !mkdir dqn_training
# %cd dqn_training
# Out:
# /content/drive/MyDrive
# 'Colab Notebooks'   disc_weights_14.h5	 gen_weights_14.h5   outputs   seed.txt   weights.h5
# /content/drive/MyDrive/dqn_training

# %%
# !git clone https://github.com/dercodeKoenig/dqn_trading_gcloudvm.git
# %cd dqn_trading_gcloudvm/t1
# Out:
# Cloning into 'dqn_trading_gcloudvm'...
# remote: Enumerating objects: 3527, done.
# remote: Counting objects: 100% (842/842), done.
# remote: Compressing objects: 100% (277/277), done.
# remote: Total 3527 (delta 646), reused 750 (delta 564), pack-reused 2685
# Receiving objects: 100% (3527/3527), 139.93 MiB | 27.50 MiB/s, done.
# Resolving deltas: 100% (2617/2617), done.
# /content/drive/MyDrive/dqn_training/dqn_trading_gcloudvm/t1

# %%
# %%writefile kaggle.json
# {"username":"bpwqsdd","key":"c01be61298c740525cfe76bfcbe1d233"}
# Out:
# Writing kaggle.json

# %%
# !mkdir ~/.kaggle
# !mv kaggle.json ~/.kaggle
# !kaggle datasets download -d bpwqsdd/us-index-cfd-data
# !mkdir data
# !unzip us-index-cfd-data.zip
# !mv *.o data/
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# ...
# 100% 1.15G/1.16G [00:08<00:00, 153MB/s]
# 100% 1.16G/1.16G [00:08<00:00, 144MB/s]
# Archive:  us-index-cfd-data.zip
#   inflating: .ipynb_checkpoints/info-checkpoint.txt
#   inflating: ENQ_1.csv
#   inflating: ENQ_1.o
#   inflating: ENQ_1_inverted.o
#   inflating: EP_1.csv
#   inflating: EP_1.o
#   inflating: EP_1_inverted.o
#   inflating: US30_1.csv
#   inflating: US30_1.o
#   inflating: US30_1_inverted.o
#   inflating: US500_1.csv
#   inflating: US500_1.o
#   inflating: US500_1_inverted.o
#   inflating: USTEC_1.csv
#   inflating: USTEC_1.o
#   inflating: USTEC_1_inverted.o
#   inflating: YM_1.csv
#   inflating: YM_1.o
#   inflating: YM_1_inverted.o
#   inflating: info.txt
#   inflating: parts_ENQ_1.o/part_000
#   inflating: parts_ENQ_1.o/part_001
#   inflating: parts_ENQ_1.o/part_002
#   inflating: parts_ENQ_1.o/part_003
#   inflating: parts_ENQ_1.o/part_004
#   inflating: parts_ENQ_1.o/part_005
# ...

# %%
# !python dqn_training_tpu.py v
# Out:
# 2024-04-19 21:15:46.804106: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:95] Opening library: /usr/local/lib/python3.10/dist-packages/tensorflow/python/platform/../../libtensorflow_cc.so.2
# 2024-04-19 21:15:46.804276: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:119] Libtpu path is: libtpu.so
# 2024-04-19 21:15:48.052744: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-19 21:16:07.268358: I external/local_xla/xla/service/service.cc:168] XLA service 0x58bdea23ef70 initialized for platform TPU (this does not guarantee that XLA will be used). Devices:
# 2024-04-19 21:16:07.268417: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): TPU, 2a886c8
# ...

# %%
# !git pull
